# %% [markdown]
# Problem Set 8
# =============

# %%
data = np.loadtxt('data.tbl')
days = data[:, 0]
v = data[:, 1]
v_e = data[:, 2]

# %%
plt.errorbar(days, v, yerr=v_e, fmt=None)
plt.plot(days, v)
